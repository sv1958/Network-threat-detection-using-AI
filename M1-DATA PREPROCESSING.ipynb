# %% [markdown]
# ## DATA PREPROCESSING AND DATA CLEANING

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('cyber1.csv')
del df['Unnamed: 0']
del df['id.orig_p']
del df['id.resp_p']
del df['proto']
del df['service']
del df['fwd_iat.min']
del df['fwd_iat.max']
del df['fwd_iat.tot']
del df['fwd_iat.avg']
del df['fwd_iat.std']
del df['bwd_iat.min']
del df['bwd_iat.max']
del df['bwd_iat.tot']
del df['bwd_iat.avg']
del df['bwd_iat.std']
del df['flow_iat.min']
del df['flow_iat.max']
del df['flow_iat.tot']
del df['flow_iat.avg']
del df['flow_iat.std']
del df['payload_bytes_per_second']
del df['fwd_subflow_pkts']
del df['bwd_subflow_pkts']
del df['fwd_subflow_bytes']
del df['bwd_subflow_bytes']
del df['fwd_bulk_bytes']
del df['bwd_bulk_bytes']
del df['active.min']
del df['active.max']
del df['active.tot']
del df['active.avg']
del df['active.std']
del df['idle.min']
del df['idle.max']
del df['idle.tot']
del df['idle.avg']
del df['idle.std']

df.head()
# Out:
#    flow_duration  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0      32.011598             9             5                  3
# 1      31.883584             9             5                  3
# 2      32.124053             9             5                  3
# 3      31.961063             9             5                  3
# 4      31.902362             9             5                  3
#
#    bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  flow_pkts_per_sec  \
# 0                  3          0.281148          0.156193           0.437341
# 1                  3          0.282277          0.156821           0.439097
# 2                  3          0.280164          0.155647           0.435811
# 3                  3          0.281593          0.156440           0.438033
# 4                  3          0.282111          0.156728           0.438839
#
#    down_up_ratio  fwd_header_size_tot  ...  flow_pkts_payload.avg  \
# 0       0.555556                  296  ...               7.714286
# 1       0.555556                  296  ...               7.714286
# 2       0.555556                  296  ...               7.428571
# 3       0.555556                  296  ...               7.428571
# 4       0.555556                  296  ...               7.714286
#
#    flow_pkts_payload.std  fwd_bulk_packets  bwd_bulk_packets  fwd_bulk_rate  \
# 0              11.618477               0.0               0.0            0.0
# 1              11.618477               0.0               0.0            0.0
# 2              11.229866               0.0               0.0            0.0
# 3              11.229866               0.0               0.0            0.0
# 4              11.618477               0.0               0.0            0.0
#
#    bwd_bulk_rate  fwd_init_window_size  bwd_init_window_size  \
# 0            0.0                 64240                 26847
# 1            0.0                 64240                 26847
# 2            0.0                 64240                 26847
# 3            0.0                 64240                 26847
# 4            0.0                 64240                 26847
#
#    fwd_last_window_size   Attack_type
# 0                   502  MQTT_Publish
# 1                   502  MQTT_Publish
# 2                   502  MQTT_Publish
# 3                   502  MQTT_Publish
# 4                   502  MQTT_Publish
#
# [5 rows x 48 columns]

# %%
df.tail()
# Out:
#         flow_duration  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 123112       0.000006             1             1                  0
# 123113       0.000007             1             1                  0
# 123114       0.000006             1             1                  0
# 123115       0.000006             1             1                  0
# 123116       0.000006             1             1                  0
#
#         bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  \
# 123112                  0     167772.160000     167772.160000
# 123113                  0     144631.172414     144631.172414
# 123114                  0     167772.160000     167772.160000
# 123115                  0     167772.160000     167772.160000
# 123116                  0     167772.160000     167772.160000
#
#         flow_pkts_per_sec  down_up_ratio  fwd_header_size_tot  ...  \
# 123112      335544.320000            1.0                   20  ...
# 123113      289262.344828            1.0                   20  ...
# 123114      335544.320000            1.0                   20  ...
# 123115      335544.320000            1.0                   20  ...
# 123116      335544.320000            1.0                   20  ...
#
#         flow_pkts_payload.avg  flow_pkts_payload.std  fwd_bulk_packets  \
# 123112                    0.0                    0.0               0.0
# 123113                    0.0                    0.0               0.0
# 123114                    0.0                    0.0               0.0
# 123115                    0.0                    0.0               0.0
# 123116                    0.0                    0.0               0.0
#
#         bwd_bulk_packets  fwd_bulk_rate  bwd_bulk_rate  fwd_init_window_size  \
# 123112               0.0            0.0            0.0                  1024
# 123113               0.0            0.0            0.0                  1024
# 123114               0.0            0.0            0.0                  1024
# 123115               0.0            0.0            0.0                  1024
# 123116               0.0            0.0            0.0                  1024
#
#         bwd_init_window_size  fwd_last_window_size          Attack_type
# 123112                     0                  1024  NMAP_XMAS_TREE_SCAN
# 123113                     0                  1024  NMAP_XMAS_TREE_SCAN
# 123114                     0                  1024  NMAP_XMAS_TREE_SCAN
# 123115                     0                  1024  NMAP_XMAS_TREE_SCAN
# 123116                     0                  1024  NMAP_XMAS_TREE_SCAN
#
# [5 rows x 48 columns]

# %%
df.shape
# Out:
# (123117, 48)

# %%
df.size
# Out:
# 5909616

# %%
df.columns
# Out:
# Index(['flow_duration', 'fwd_pkts_tot', 'bwd_pkts_tot', 'fwd_data_pkts_tot',
#        'bwd_data_pkts_tot', 'fwd_pkts_per_sec', 'bwd_pkts_per_sec',
#        'flow_pkts_per_sec', 'down_up_ratio', 'fwd_header_size_tot',
#        'fwd_header_size_min', 'fwd_header_size_max', 'bwd_header_size_tot',
#        'bwd_header_size_min', 'bwd_header_size_max', 'flow_FIN_flag_count',
#        'flow_SYN_flag_count', 'flow_RST_flag_count', 'fwd_PSH_flag_count',
#        'bwd_PSH_flag_count', 'flow_ACK_flag_count', 'fwd_URG_flag_count',
#        'bwd_URG_flag_count', 'flow_CWR_flag_count', 'flow_ECE_flag_count',
#        'fwd_pkts_payload.min', 'fwd_pkts_payload.max', 'fwd_pkts_payload.tot',
#        'fwd_pkts_payload.avg', 'fwd_pkts_payload.std', 'bwd_pkts_payload.min',
#        'bwd_pkts_payload.max', 'bwd_pkts_payload.tot', 'bwd_pkts_payload.avg',
#        'bwd_pkts_payload.std', 'flow_pkts_payload.min',
#        'flow_pkts_payload.max', 'flow_pkts_payload.tot',
#        'flow_pkts_payload.avg', 'flow_pkts_payload.std', 'fwd_bulk_packets',
#        'bwd_bulk_packets', 'fwd_bulk_rate', 'bwd_bulk_rate',
#        'fwd_init_window_size', 'bwd_init_window_size', 'fwd_last_window_size',
#        'Attack_type'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Attack_type']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
df.isnull()
# Out:
#         flow_duration  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0               False         False         False              False
# 1               False         False         False              False
# 2               False         False         False              False
# 3               False         False         False              False
# 4               False         False         False              False
# ...               ...           ...           ...                ...
# 123112          False         False         False              False
# 123113          False         False         False              False
# 123114          False         False         False              False
# 123115          False         False         False              False
# 123116          False         False         False              False
#
#         bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  \
# 0                   False             False             False
# 1                   False             False             False
# 2                   False             False             False
# 3                   False             False             False
# 4                   False             False             False
# ...                   ...               ...               ...
# 123112              False             False             False
# 123113              False             False             False
# 123114              False             False             False
# 123115              False             False             False
# 123116              False             False             False
#
#         flow_pkts_per_sec  down_up_ratio  fwd_header_size_tot  ...  \
# 0                   False          False                False  ...
# 1                   False          False                False  ...
# 2                   False          False                False  ...
# 3                   False          False                False  ...
# 4                   False          False                False  ...
# ...                   ...            ...                  ...  ...
# 123112              False          False                False  ...
# 123113              False          False                False  ...
# 123114              False          False                False  ...
# 123115              False          False                False  ...
# 123116              False          False                False  ...
#
#         flow_pkts_payload.avg  flow_pkts_payload.std  fwd_bulk_packets  \
# 0                       False                  False             False
# 1                       False                  False             False
# 2                       False                  False             False
# 3                       False                  False             False
# 4                       False                  False             False
# ...                       ...                    ...               ...
# 123112                  False                  False             False
# 123113                  False                  False             False
# 123114                  False                  False             False
# 123115                  False                  False             False
# 123116                  False                  False             False
#
#         bwd_bulk_packets  fwd_bulk_rate  bwd_bulk_rate  fwd_init_window_size  \
# 0                  False          False          False                 False
# 1                  False          False          False                 False
# 2                  False          False          False                 False
# 3                  False          False          False                 False
# 4                  False          False          False                 False
# ...                  ...            ...            ...                   ...
# 123112             False          False          False                 False
# 123113             False          False          False                 False
# 123114             False          False          False                 False
# 123115             False          False          False                 False
# 123116             False          False          False                 False
#
#         bwd_init_window_size  fwd_last_window_size  Attack_type
# 0                      False                 False        False
# 1                      False                 False        False
# 2                      False                 False        False
# 3                      False                 False        False
# 4                      False                 False        False
# ...                      ...                   ...          ...
# 123112                 False                 False        False
# 123113                 False                 False        False
# 123114                 False                 False        False
# 123115                 False                 False        False
# 123116                 False                 False        False
#
# [123117 rows x 48 columns]

# %%
df = df.dropna()

# %%
df['Attack_type'].unique()
# Out:
# array([ 3, 10, 11,  0,  1,  2,  4,  5,  6,  7,  8,  9])

# %%
df.describe()
# Out:
#        flow_duration   fwd_pkts_tot   bwd_pkts_tot  fwd_data_pkts_tot  \
# count  123117.000000  123117.000000  123117.000000      123117.000000
# mean        3.809566       2.268826       1.909509           1.471218
# std       130.005408      22.336565      33.018311          19.635196
# min         0.000000       0.000000       0.000000           0.000000
# 25%         0.000001       1.000000       1.000000           1.000000
# 50%         0.000004       1.000000       1.000000           1.000000
# 75%         0.000005       1.000000       1.000000           1.000000
# max     21728.335578    4345.000000   10112.000000        4345.000000
#
#        bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  \
# count      123117.000000      1.231170e+05      1.231170e+05
# mean            0.820260      3.518063e+05      3.517620e+05
# std            32.293948      3.707645e+05      3.708015e+05
# min             0.000000      0.000000e+00      0.000000e+00
# 25%             0.000000      7.454354e+01      7.288927e+01
# 50%             0.000000      2.467238e+05      2.467238e+05
# 75%             0.000000      5.242880e+05      5.242880e+05
# max         10105.000000      1.048576e+06      1.048576e+06
#
#        flow_pkts_per_sec  down_up_ratio  fwd_header_size_tot  ...  \
# count       1.231170e+05  123117.000000        123117.000000  ...
# mean        7.035683e+05       0.854571            53.892379  ...
# std         7.415634e+05       0.337640           393.027195  ...
# min         0.000000e+00       0.000000             0.000000  ...
# 25%         1.490871e+02       1.000000            20.000000  ...
# 50%         4.934475e+05       1.000000            20.000000  ...
# 75%         1.048576e+06       1.000000            20.000000  ...
# max         2.097152e+06       6.087899         69296.000000  ...
#
#        flow_pkts_payload.avg  flow_pkts_payload.std  fwd_bulk_packets  \
# count          123117.000000          123117.000000     123117.000000
# mean               65.010194              76.041654          0.024144
# std                50.412145              74.019903          1.484759
# min                 0.000000               0.000000          0.000000
# 25%                60.000000              50.219518          0.000000
# 50%                60.000000              84.852814          0.000000
# 75%                60.000000              84.852814          0.000000
# max              1156.084685             924.651958        343.000000
#
#        bwd_bulk_packets  fwd_bulk_rate  bwd_bulk_rate  fwd_init_window_size  \
# count     123117.000000   1.231170e+05   1.231170e+05         123117.000000
# mean           0.131113   3.835746e+03   4.841460e+04           6118.905123
# std           14.546545   3.080334e+05   6.852480e+05          18716.313861
# min            0.000000   0.000000e+00   0.000000e+00              0.000000
# 25%            0.000000   0.000000e+00   0.000000e+00             64.000000
# 50%            0.000000   0.000000e+00   0.000000e+00             64.000000
# 75%            0.000000   0.000000e+00   0.000000e+00             64.000000
# max         5052.500000   4.633628e+07   2.830087e+07          65535.000000
#
#        bwd_init_window_size  fwd_last_window_size    Attack_type
# count         123117.000000         123117.000000  123117.000000
# mean            2739.776018            751.647514       2.796243
# std            10018.848534           6310.183843       2.461914
# min                0.000000              0.000000       0.000000
# 25%                0.000000             64.000000       2.000000
# 50%                0.000000             64.000000       2.000000
# 75%                0.000000             64.000000       2.000000
# max            65535.000000          65535.000000      11.000000
#
# [8 rows x 48 columns]

# %%
df.corr()
# Out:
#                        flow_duration  fwd_pkts_tot  bwd_pkts_tot  \
# flow_duration               1.000000      0.741707      0.071395
# fwd_pkts_tot                0.741707      1.000000      0.407452
# bwd_pkts_tot                0.071395      0.407452      1.000000
# fwd_data_pkts_tot           0.754355      0.914683      0.094172
# bwd_data_pkts_tot           0.058859      0.379742      0.992956
# fwd_pkts_per_sec           -0.027805     -0.053855     -0.026131
# bwd_pkts_per_sec           -0.027799     -0.053875     -0.026121
# flow_pkts_per_sec          -0.027802     -0.053865     -0.026126
# down_up_ratio              -0.022214     -0.004033      0.067763
# fwd_header_size_tot         0.472366      0.808293      0.700118
# fwd_header_size_min         0.028291      0.050107      0.034369
# fwd_header_size_max         0.043995      0.100720      0.067977
# bwd_header_size_tot         0.056805      0.390633      0.985229
# bwd_header_size_min         0.020670      0.045252      0.040903
# bwd_header_size_max         0.035540      0.078916      0.060067
# flow_FIN_flag_count         0.028497      0.114753      0.082985
# flow_SYN_flag_count         0.035622      0.078495      0.051799
# flow_RST_flag_count        -0.017495     -0.018870     -0.003992
# fwd_PSH_flag_count          0.404517      0.364582      0.248922
# bwd_PSH_flag_count          0.290758      0.466812      0.448920
# flow_ACK_flag_count         0.137856      0.448747      0.957675
# fwd_URG_flag_count         -0.003771     -0.007311     -0.003568
# bwd_URG_flag_count               NaN           NaN           NaN
# flow_CWR_flag_count         0.004870      0.023741      0.017330
# flow_ECE_flag_count         0.006021      0.025846      0.019376
# fwd_pkts_payload.min       -0.044123     -0.095469     -0.062117
# fwd_pkts_payload.max        0.041348      0.140729      0.112475
# fwd_pkts_payload.tot        0.532682      0.761746      0.175128
# fwd_pkts_payload.avg       -0.016358     -0.006363     -0.003508
# fwd_pkts_payload.std        0.042481      0.135598      0.096076
# bwd_pkts_payload.min       -0.001475     -0.000552      0.004245
# bwd_pkts_payload.max        0.044537      0.164519      0.132944
# bwd_pkts_payload.tot        0.009881      0.337806      0.975332
# bwd_pkts_payload.avg        0.026575      0.161659      0.173094
# bwd_pkts_payload.std        0.029057      0.128678      0.092212
# flow_pkts_payload.min       0.013989      0.010076     -0.015310
# flow_pkts_payload.max       0.042583      0.161276      0.130971
# flow_pkts_payload.tot       0.069523      0.419143      0.983072
# flow_pkts_payload.avg       0.020875      0.150785      0.176085
# flow_pkts_payload.std       0.014524      0.123511      0.118384
# fwd_bulk_packets            0.013955      0.128814      0.083113
# bwd_bulk_packets            0.005651      0.237382      0.891658
# fwd_bulk_rate               0.006516      0.021227      0.013216
# bwd_bulk_rate               0.014966      0.059976      0.047894
# fwd_init_window_size        0.057173      0.132710      0.079270
# bwd_init_window_size        0.060731      0.147478      0.104156
# fwd_last_window_size        0.003591      0.008330      0.012885
# Attack_type                 0.024384      0.041568      0.006562
#
#                        fwd_data_pkts_tot  bwd_data_pkts_tot  fwd_pkts_per_sec  \
# flow_duration                   0.754355           0.058859         -0.027805
# fwd_pkts_tot                    0.914683           0.379742         -0.053855
# bwd_pkts_tot                    0.094172           0.992956         -0.026131
# fwd_data_pkts_tot               1.000000           0.070199         -0.024081
# bwd_data_pkts_tot               0.070199           1.000000         -0.024083
# fwd_pkts_per_sec               -0.024081          -0.024083          1.000000
# bwd_pkts_per_sec               -0.024080          -0.024076          0.999986
# flow_pkts_per_sec              -0.024081          -0.024080          0.999997
# down_up_ratio                  -0.009794           0.060122          0.408345
# fwd_header_size_tot             0.527557           0.648995         -0.081298
# fwd_header_size_min            -0.004278           0.012940          0.072714
# fwd_header_size_max             0.013529           0.041261         -0.059693
# bwd_header_size_tot             0.070236           0.977200         -0.024575
# bwd_header_size_min            -0.003271           0.018831          0.272639
# bwd_header_size_max             0.010279           0.033038          0.157488
# flow_FIN_flag_count             0.032687           0.054602         -0.214539
# flow_SYN_flag_count             0.009312           0.027678          0.062209
# flow_RST_flag_count            -0.025732          -0.010174          0.441293
# fwd_PSH_flag_count              0.230279           0.158069         -0.082365
# bwd_PSH_flag_count              0.167207           0.391543         -0.062173
# flow_ACK_flag_count             0.098170           0.935727         -0.038212
# fwd_URG_flag_count             -0.009643          -0.003269         -0.061426
# bwd_URG_flag_count                   NaN                NaN               NaN
# flow_CWR_flag_count             0.006272           0.012704         -0.021385
# flow_ECE_flag_count             0.006762           0.014477         -0.021060
# fwd_pkts_payload.min           -0.022240          -0.048446          0.427702
# fwd_pkts_payload.max            0.082933           0.087021         -0.031845
# fwd_pkts_payload.tot            0.799042           0.112295         -0.020633
# fwd_pkts_payload.avg            0.039842          -0.009540          0.332284
# fwd_pkts_payload.std            0.076360           0.069363         -0.170680
# bwd_pkts_payload.min            0.007270           0.010906         -0.183730
# bwd_pkts_payload.max            0.064271           0.105884         -0.214843
# bwd_pkts_payload.tot            0.036185           0.991961         -0.011467
# bwd_pkts_payload.avg            0.053204           0.159701         -0.213230
# bwd_pkts_payload.std            0.047591           0.070134         -0.208720
# flow_pkts_payload.min           0.026985          -0.002765         -0.362199
# flow_pkts_payload.max           0.066937           0.103167         -0.138328
# flow_pkts_payload.tot           0.125388           0.992449         -0.013642
# flow_pkts_payload.avg           0.076631           0.166414         -0.125397
# flow_pkts_payload.std           0.048724           0.093953          0.082773
# fwd_bulk_packets                0.107989           0.047856         -0.015429
# bwd_bulk_packets                0.004657           0.909324         -0.008552
# fwd_bulk_rate                   0.013287           0.007693         -0.011816
# bwd_bulk_rate                   0.022539           0.039957         -0.067038
# fwd_init_window_size            0.035651           0.053777         -0.274301
# bwd_init_window_size            0.046718           0.072643         -0.259457
# fwd_last_window_size           -0.003717           0.011146         -0.007777
# Attack_type                     0.018883           0.004657         -0.251517
#
#                        bwd_pkts_per_sec  flow_pkts_per_sec  down_up_ratio  \
# flow_duration                 -0.027799          -0.027802      -0.022214
# fwd_pkts_tot                  -0.053875          -0.053865      -0.004033
# bwd_pkts_tot                  -0.026121          -0.026126       0.067763
# fwd_data_pkts_tot             -0.024080          -0.024081      -0.009794
# bwd_data_pkts_tot             -0.024076          -0.024080       0.060122
# fwd_pkts_per_sec               0.999986           0.999997       0.408345
# bwd_pkts_per_sec               1.000000           0.999997       0.408605
# flow_pkts_per_sec              0.999997           1.000000       0.408476
# down_up_ratio                  0.408605           0.408476       1.000000
# fwd_header_size_tot           -0.081342          -0.081320       0.003847
# fwd_header_size_min            0.072696           0.072705       0.105638
# fwd_header_size_max           -0.060010          -0.059852       0.031023
# bwd_header_size_tot           -0.024566          -0.024570       0.053966
# bwd_header_size_min            0.272875           0.272758       0.687193
# bwd_header_size_max            0.157705           0.157597       0.561921
# flow_FIN_flag_count           -0.214698          -0.214619       0.003402
# flow_SYN_flag_count            0.061977           0.062093       0.056665
# flow_RST_flag_count            0.441195           0.441246       0.655790
# fwd_PSH_flag_count            -0.082397          -0.082381      -0.016035
# bwd_PSH_flag_count            -0.062159          -0.062166       0.005718
# flow_ACK_flag_count           -0.038214          -0.038213       0.044583
# fwd_URG_flag_count            -0.061405          -0.061416       0.053153
# bwd_URG_flag_count                  NaN                NaN            NaN
# flow_CWR_flag_count           -0.021380          -0.021382       0.010392
# flow_ECE_flag_count           -0.021056          -0.021058       0.015176
# fwd_pkts_payload.min           0.427911           0.427808       0.201492
# fwd_pkts_payload.max          -0.031828          -0.031837       0.116793
# fwd_pkts_payload.tot          -0.020630          -0.020631      -0.001654
# fwd_pkts_payload.avg           0.332451           0.332369       0.218647
# fwd_pkts_payload.std          -0.170754          -0.170717       0.035164
# bwd_pkts_payload.min          -0.183689          -0.183710       0.066915
# bwd_pkts_payload.max          -0.214794          -0.214819       0.035601
# bwd_pkts_payload.tot          -0.011463          -0.011465       0.059232
# bwd_pkts_payload.avg          -0.213181          -0.213206       0.074205
# bwd_pkts_payload.std          -0.208672          -0.208697       0.025151
# flow_pkts_payload.min         -0.362120          -0.362161      -0.758942
# flow_pkts_payload.max         -0.138292          -0.138311       0.069713
# flow_pkts_payload.tot         -0.013638          -0.013640       0.058323
# flow_pkts_payload.avg         -0.125283          -0.125340      -0.103406
# flow_pkts_payload.std          0.082820           0.082796       0.384253
# fwd_bulk_packets              -0.015426          -0.015428      -0.001780
# bwd_bulk_packets              -0.008549          -0.008550       0.051141
# fwd_bulk_rate                 -0.011813          -0.011814      -0.002376
# bwd_bulk_rate                 -0.067022          -0.067030       0.025836
# fwd_init_window_size          -0.274652          -0.274478      -0.119897
# bwd_init_window_size          -0.259403          -0.259431      -0.066584
# fwd_last_window_size          -0.007762          -0.007770       0.012264
# Attack_type                   -0.251580          -0.251550      -0.068656
#
#                        fwd_header_size_tot  ...  flow_pkts_payload.avg  \
# flow_duration                     0.472366  ...               0.020875
# fwd_pkts_tot                      0.808293  ...               0.150785
# bwd_pkts_tot                      0.700118  ...               0.176085
# fwd_data_pkts_tot                 0.527557  ...               0.076631
# bwd_data_pkts_tot                 0.648995  ...               0.166414
# fwd_pkts_per_sec                 -0.081298  ...              -0.125397
# bwd_pkts_per_sec                 -0.081342  ...              -0.125283
# flow_pkts_per_sec                -0.081320  ...              -0.125340
# down_up_ratio                     0.003847  ...              -0.103406
# fwd_header_size_tot               1.000000  ...               0.213170
# fwd_header_size_min               0.141813  ...              -0.061241
# fwd_header_size_max               0.221948  ...               0.083431
# bwd_header_size_tot               0.702624  ...               0.148293
# bwd_header_size_min               0.119451  ...              -0.153364
# bwd_header_size_max               0.177810  ...              -0.067508
# flow_FIN_flag_count               0.212947  ...               0.297215
# flow_SYN_flag_count               0.182892  ...               0.185047
# flow_RST_flag_count              -0.001218  ...              -0.115495
# fwd_PSH_flag_count                0.611368  ...               0.101700
# bwd_PSH_flag_count                0.802574  ...               0.180083
# flow_ACK_flag_count               0.802144  ...               0.168063
# fwd_URG_flag_count               -0.011098  ...              -0.165967
# bwd_URG_flag_count                     NaN  ...                    NaN
# flow_CWR_flag_count               0.040576  ...               0.085872
# flow_ECE_flag_count               0.042837  ...               0.085138
# fwd_pkts_payload.min             -0.174524  ...               0.078413
# fwd_pkts_payload.max              0.212097  ...               0.749443
# fwd_pkts_payload.tot              0.586532  ...               0.144585
# fwd_pkts_payload.avg             -0.036315  ...               0.451498
# fwd_pkts_payload.std              0.213509  ...               0.649330
# bwd_pkts_payload.min             -0.017942  ...               0.139349
# bwd_pkts_payload.max              0.273560  ...               0.683809
# bwd_pkts_payload.tot              0.590339  ...               0.149201
# bwd_pkts_payload.avg              0.256215  ...               0.785585
# bwd_pkts_payload.std              0.215946  ...               0.664461
# flow_pkts_payload.min            -0.022039  ...               0.361186
# flow_pkts_payload.max             0.266288  ...               0.744979
# flow_pkts_payload.tot             0.648935  ...               0.163601
# flow_pkts_payload.avg             0.213170  ...               1.000000
# flow_pkts_payload.std             0.208190  ...               0.692121
# fwd_bulk_packets                  0.209942  ...               0.127720
# bwd_bulk_packets                  0.436802  ...               0.115936
# fwd_bulk_rate                     0.036565  ...               0.074719
# bwd_bulk_rate                     0.096466  ...               0.353473
# fwd_init_window_size              0.255107  ...               0.097001
# bwd_init_window_size              0.275949  ...               0.202142
# fwd_last_window_size              0.017727  ...              -0.119173
# Attack_type                       0.045860  ...              -0.140679
#
#                        flow_pkts_payload.std  fwd_bulk_packets  \
# flow_duration                       0.014524          0.013955
# fwd_pkts_tot                        0.123511          0.128814
# bwd_pkts_tot                        0.118384          0.083113
# fwd_data_pkts_tot                   0.048724          0.107989
# bwd_data_pkts_tot                   0.093953          0.047856
# fwd_pkts_per_sec                    0.082773         -0.015429
# bwd_pkts_per_sec                    0.082820         -0.015426
# flow_pkts_per_sec                   0.082796         -0.015428
# down_up_ratio                       0.384253         -0.001780
# fwd_header_size_tot                 0.208190          0.209942
# fwd_header_size_min                 0.192002          0.013896
# fwd_header_size_max                 0.368592          0.029012
# bwd_header_size_tot                 0.103912          0.076067
# bwd_header_size_min                 0.453721          0.004634
# bwd_header_size_max                 0.509730          0.022754
# flow_FIN_flag_count                 0.531228          0.052152
# flow_SYN_flag_count                 0.429541          0.022082
# flow_RST_flag_count                 0.355774         -0.001688
# fwd_PSH_flag_count                  0.156965          0.097593
# bwd_PSH_flag_count                  0.180935          0.108618
# flow_ACK_flag_count                 0.137777          0.119081
# fwd_URG_flag_count                 -0.132214         -0.002093
# bwd_URG_flag_count                       NaN               NaN
# flow_CWR_flag_count                 0.093244          0.036725
# flow_ECE_flag_count                 0.086395          0.033883
# fwd_pkts_payload.min               -0.050865         -0.029597
# fwd_pkts_payload.max                0.813693          0.126256
# fwd_pkts_payload.tot                0.109721          0.461939
# fwd_pkts_payload.avg                0.335992          0.167283
# fwd_pkts_payload.std                0.726263          0.120121
# bwd_pkts_payload.min               -0.056590         -0.000730
# bwd_pkts_payload.max                0.835874          0.089637
# bwd_pkts_payload.tot                0.075463          0.035911
# bwd_pkts_payload.avg                0.797077          0.040412
# bwd_pkts_payload.std                0.843727          0.044938
# flow_pkts_payload.min              -0.349144         -0.000088
# flow_pkts_payload.max               0.896262          0.095741
# flow_pkts_payload.tot               0.086852          0.087298
# flow_pkts_payload.avg               0.692121          0.127720
# flow_pkts_payload.std               1.000000          0.088793
# fwd_bulk_packets                    0.088793          1.000000
# bwd_bulk_packets                    0.058023          0.006575
# fwd_bulk_rate                       0.079758          0.063348
# bwd_bulk_rate                       0.400865          0.014708
# fwd_init_window_size                0.325107          0.038706
# bwd_init_window_size                0.411245          0.061076
# fwd_last_window_size               -0.085228          0.000403
# Attack_type                        -0.039307         -0.007435
#
#                        bwd_bulk_packets  fwd_bulk_rate  bwd_bulk_rate  \
# flow_duration                  0.005651       0.006516       0.014966
# fwd_pkts_tot                   0.237382       0.021227       0.059976
# bwd_pkts_tot                   0.891658       0.013216       0.047894
# fwd_data_pkts_tot              0.004657       0.013287       0.022539
# bwd_data_pkts_tot              0.909324       0.007693       0.039957
# fwd_pkts_per_sec              -0.008552      -0.011816      -0.067038
# bwd_pkts_per_sec              -0.008549      -0.011813      -0.067022
# flow_pkts_per_sec             -0.008550      -0.011814      -0.067030
# down_up_ratio                  0.051141      -0.002376       0.025836
# fwd_header_size_tot            0.436802       0.036565       0.096466
# fwd_header_size_min            0.011198       0.024368       0.033304
# fwd_header_size_max            0.027289       0.032248       0.156279
# bwd_header_size_tot            0.913159       0.012475       0.041186
# bwd_header_size_min            0.011583       0.012805       0.086233
# bwd_header_size_max            0.018486       0.027036       0.131877
# flow_FIN_flag_count            0.033902       0.046989       0.242137
# flow_SYN_flag_count            0.018812       0.026516       0.128222
# flow_RST_flag_count           -0.002946      -0.011045       0.071350
# fwd_PSH_flag_count             0.016845       0.029748       0.077613
# bwd_PSH_flag_count             0.088533       0.024571       0.084471
# flow_ACK_flag_count            0.832483       0.020116       0.056494
# fwd_URG_flag_count            -0.001160      -0.001603      -0.009093
# bwd_URG_flag_count                  NaN            NaN            NaN
# flow_CWR_flag_count            0.010432       0.004946       0.056044
# flow_ECE_flag_count            0.011034       0.003810       0.044660
# fwd_pkts_payload.min          -0.018879      -0.026269      -0.145010
# fwd_pkts_payload.max           0.028971       0.126575       0.331289
# fwd_pkts_payload.tot           0.008579       0.047908       0.030133
# fwd_pkts_payload.avg          -0.009221       0.091242      -0.001499
# fwd_pkts_payload.std           0.020174       0.155809       0.304309
# bwd_pkts_payload.min          -0.001192      -0.002062      -0.002705
# bwd_pkts_payload.max           0.061312       0.075134       0.406746
# bwd_pkts_payload.tot           0.930067       0.004311       0.027910
# bwd_pkts_payload.avg           0.105617       0.037086       0.442015
# bwd_pkts_payload.std           0.035384       0.058867       0.433864
# flow_pkts_payload.min         -0.003137      -0.004525      -0.021149
# flow_pkts_payload.max          0.061238       0.081472       0.401441
# flow_pkts_payload.tot          0.919675       0.009633       0.030950
# flow_pkts_payload.avg          0.115936       0.074719       0.353473
# flow_pkts_payload.std          0.058023       0.079758       0.400865
# fwd_bulk_packets               0.006575       0.063348       0.014708
# bwd_bulk_packets               1.000000       0.002422       0.034185
# fwd_bulk_rate                  0.002422       1.000000       0.032841
# bwd_bulk_rate                  0.034185       0.032841       1.000000
# fwd_init_window_size           0.026605       0.037760       0.193998
# bwd_init_window_size           0.042459       0.048264       0.193945
# fwd_last_window_size           0.011325      -0.000450       0.010884
# Attack_type                    0.000774      -0.013531       0.057052
#
#                        fwd_init_window_size  bwd_init_window_size  \
# flow_duration                      0.057173              0.060731
# fwd_pkts_tot                       0.132710              0.147478
# bwd_pkts_tot                       0.079270              0.104156
# fwd_data_pkts_tot                  0.035651              0.046718
# bwd_data_pkts_tot                  0.053777              0.072643
# fwd_pkts_per_sec                  -0.274301             -0.259457
# bwd_pkts_per_sec                  -0.274652             -0.259403
# flow_pkts_per_sec                 -0.274478             -0.259431
# down_up_ratio                     -0.119897             -0.066584
# fwd_header_size_tot                0.255107              0.275949
# fwd_header_size_min                0.665375              0.507595
# fwd_header_size_max                0.863323              0.721657
# bwd_header_size_tot                0.085080              0.108554
# bwd_header_size_min                0.455951              0.428884
# bwd_header_size_max                0.629733              0.610730
# flow_FIN_flag_count                0.623803              0.667196
# flow_SYN_flag_count                0.655410              0.612853
# flow_RST_flag_count               -0.018907             -0.032686
# fwd_PSH_flag_count                 0.247753              0.282388
# bwd_PSH_flag_count                 0.193573              0.222027
# flow_ACK_flag_count                0.135405              0.162482
# fwd_URG_flag_count                -0.035034             -0.035194
# bwd_URG_flag_count                      NaN                   NaN
# flow_CWR_flag_count                0.071547              0.090257
# flow_ECE_flag_count                0.069614              0.076807
# fwd_pkts_payload.min              -0.688097             -0.581393
# fwd_pkts_payload.max               0.257843              0.370354
# fwd_pkts_payload.tot               0.041831              0.057437
# fwd_pkts_payload.avg              -0.461873             -0.324565
# fwd_pkts_payload.std               0.441361              0.498354
# bwd_pkts_payload.min              -0.063635             -0.053221
# bwd_pkts_payload.max               0.558273              0.604204
# bwd_pkts_payload.tot               0.029794              0.047945
# bwd_pkts_payload.avg               0.434954              0.471631
# bwd_pkts_payload.std               0.573241              0.596463
# flow_pkts_payload.min             -0.124015             -0.104495
# flow_pkts_payload.max              0.484847              0.565781
# flow_pkts_payload.tot              0.034124              0.053804
# flow_pkts_payload.avg              0.097001              0.202142
# flow_pkts_payload.std              0.325107              0.411245
# fwd_bulk_packets                   0.038706              0.061076
# bwd_bulk_packets                   0.026605              0.042459
# fwd_bulk_rate                      0.037760              0.048264
# bwd_bulk_rate                      0.193998              0.193945
# fwd_init_window_size               1.000000              0.834001
# bwd_init_window_size               0.834001              1.000000
# fwd_last_window_size               0.323171             -0.002234
# Attack_type                        0.311407              0.178757
#
#                        fwd_last_window_size  Attack_type
# flow_duration                      0.003591     0.024384
# fwd_pkts_tot                       0.008330     0.041568
# bwd_pkts_tot                       0.012885     0.006562
# fwd_data_pkts_tot                 -0.003717     0.018883
# bwd_data_pkts_tot                  0.011146     0.004657
# fwd_pkts_per_sec                  -0.007777    -0.251517
# bwd_pkts_per_sec                  -0.007762    -0.251580
# flow_pkts_per_sec                 -0.007770    -0.251550
# down_up_ratio                      0.012264    -0.068656
# fwd_header_size_tot                0.017727     0.045860
# fwd_header_size_min                0.371815    -0.045636
# fwd_header_size_max                0.282692     0.093328
# bwd_header_size_tot                0.012295     0.007596
# bwd_header_size_min                0.017327     0.013049
# bwd_header_size_max                0.015435     0.068419
# flow_FIN_flag_count                0.019293     0.408962
# flow_SYN_flag_count                0.045623    -0.160192
# flow_RST_flag_count                0.013607    -0.232254
# fwd_PSH_flag_count                 0.013240     0.048538
# bwd_PSH_flag_count                 0.010643     0.024920
# flow_ACK_flag_count                0.015911     0.015865
# fwd_URG_flag_count                 0.005555     0.324308
# bwd_URG_flag_count                      NaN          NaN
# flow_CWR_flag_count                0.053448     0.067497
# flow_ECE_flag_count                0.068517     0.067148
# fwd_pkts_payload.min              -0.232575    -0.604627
# fwd_pkts_payload.max              -0.081066    -0.132501
# fwd_pkts_payload.tot              -0.002222    -0.000402
# fwd_pkts_payload.avg              -0.227288    -0.569125
# fwd_pkts_payload.std               0.002611     0.078263
# bwd_pkts_payload.min              -0.023168     0.102869
# bwd_pkts_payload.max               0.002296     0.226805
# bwd_pkts_payload.tot               0.010365    -0.002489
# bwd_pkts_payload.avg              -0.003948     0.197071
# bwd_pkts_payload.std               0.001178     0.256941
# flow_pkts_payload.min             -0.042816    -0.016909
# flow_pkts_payload.max             -0.044738     0.099402
# flow_pkts_payload.tot              0.009989    -0.002504
# flow_pkts_payload.avg             -0.119173    -0.140679
# flow_pkts_payload.std             -0.085228    -0.039307
# fwd_bulk_packets                   0.000403    -0.007435
# bwd_bulk_packets                   0.011325     0.000774
# fwd_bulk_rate                     -0.000450    -0.013531
# bwd_bulk_rate                      0.010884     0.057052
# fwd_init_window_size               0.323171     0.311407
# bwd_init_window_size              -0.002234     0.178757
# fwd_last_window_size               1.000000     0.155755
# Attack_type                        0.155755     1.000000
#
# [48 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123117 entries, 0 to 123116
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   flow_duration          123117 non-null  float64
#  1   fwd_pkts_tot           123117 non-null  int64
#  2   bwd_pkts_tot           123117 non-null  int64
#  3   fwd_data_pkts_tot      123117 non-null  int64
#  4   bwd_data_pkts_tot      123117 non-null  int64
#  5   fwd_pkts_per_sec       123117 non-null  float64
#  6   bwd_pkts_per_sec       123117 non-null  float64
#  7   flow_pkts_per_sec      123117 non-null  float64
#  8   down_up_ratio          123117 non-null  float64
#  9   fwd_header_size_tot    123117 non-null  int64
#  10  fwd_header_size_min    123117 non-null  int64
#  11  fwd_header_size_max    123117 non-null  int64
#  12  bwd_header_size_tot    123117 non-null  int64
#  13  bwd_header_size_min    123117 non-null  int64
#  14  bwd_header_size_max    123117 non-null  int64
#  15  flow_FIN_flag_count    123117 non-null  int64
#  16  flow_SYN_flag_count    123117 non-null  int64
#  17  flow_RST_flag_count    123117 non-null  int64
#  18  fwd_PSH_flag_count     123117 non-null  int64
#  19  bwd_PSH_flag_count     123117 non-null  int64
#  20  flow_ACK_flag_count    123117 non-null  int64
#  21  fwd_URG_flag_count     123117 non-null  int64
#  22  bwd_URG_flag_count     123117 non-null  int64
#  23  flow_CWR_flag_count    123117 non-null  int64
#  24  flow_ECE_flag_count    123117 non-null  int64
#  25  fwd_pkts_payload.min   123117 non-null  float64
#  26  fwd_pkts_payload.max   123117 non-null  float64
#  27  fwd_pkts_payload.tot   123117 non-null  float64
#  28  fwd_pkts_payload.avg   123117 non-null  float64
#  29  fwd_pkts_payload.std   123117 non-null  float64
#  30  bwd_pkts_payload.min   123117 non-null  float64
#  31  bwd_pkts_payload.max   123117 non-null  float64
#  32  bwd_pkts_payload.tot   123117 non-null  float64
#  33  bwd_pkts_payload.avg   123117 non-null  float64
#  34  bwd_pkts_payload.std   123117 non-null  float64
#  35  flow_pkts_payload.min  123117 non-null  float64
#  36  flow_pkts_payload.max  123117 non-null  float64
#  37  flow_pkts_payload.tot  123117 non-null  float64
#  38  flow_pkts_payload.avg  123117 non-null  float64
#  39  flow_pkts_payload.std  123117 non-null  float64
#  40  fwd_bulk_packets       123117 non-null  float64
#  41  bwd_bulk_packets       123117 non-null  float64
#  42  fwd_bulk_rate          123117 non-null  float64
#  43  bwd_bulk_rate          123117 non-null  float64
#  44  fwd_init_window_size   123117 non-null  int64
#  45  bwd_init_window_size   123117 non-null  int64
#  46  fwd_last_window_size   123117 non-null  int64
#  47  Attack_type            123117 non-null  int32
# dtypes: float64(24), int32(1), int64(23)
# memory usage: 44.6 MB

# %%
df["Attack_type"].value_counts()
# Out:
# Attack_type
# 2     94659
# 10     8108
# 0      7750
# 3      4146
# 8      2590
# 9      2010
# 6      2000
# 7      1002
# 1       534
# 11      253
# 4        37
# 5        28
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 123112     True
# 123113     True
# 123114     True
# 123115     True
# 123116     True
# Length: 123117, dtype: bool

# %%
sum(df.duplicated())
# Out:
# 105291

# %%
df = df.drop_duplicates()

# %%
sum(df.duplicated())
# Out:
# 0
